# %%
import cv2
import numpy as np

signA_classifier = cv2.CascadeClassifier('sign_language-A-Classifier.xml')
signB_classifier = cv2.CascadeClassifier('sign_language-B-Classifier.xml')
signC_classifier = cv2.CascadeClassifier('sign_language-C-Classifier.xml')
signD_classifier = cv2.CascadeClassifier('sign_language-D-Classifier.xml')
signF_classifier = cv2.CascadeClassifier('sign_language-F-Classifier.xml')
signR_classifier = cv2.CascadeClassifier('sign_language-R-Classifier.xml')


def signA_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsA = signA_classifier.detectMultiScale(gray, 1.3, 5)
    if signsA is ():
        return img, []
    
    for (x,y,w,h) in signsA:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

def signB_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsB = signB_classifier.detectMultiScale(gray, 1.3, 5)
    if signsB is ():
        return img, []
    
    for (x,y,w,h) in signsB:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

def signC_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsC = signC_classifier.detectMultiScale(gray, 1.3, 5)
    if signsC is ():
        return img, []
    
    for (x,y,w,h) in signsC:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

def signD_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsD = signD_classifier.detectMultiScale(gray, 1.3, 5)
    if signsD is ():
        return img, []
    
    for (x,y,w,h) in signsD:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

def signD_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsD = signD_classifier.detectMultiScale(gray, 1.3, 5)
    if signsD is ():
        return img, []
    
    for (x,y,w,h) in signsD:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

def signF_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsF = signF_classifier.detectMultiScale(gray, 1.3, 5)
    if signsF is ():
        return img, []
    
    for (x,y,w,h) in signsF:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi

def signR_detector(img, size=0.5):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    signsR = signR_classifier.detectMultiScale(gray, 1.3, 5)
    if signsR is ():
        return img, []
    
    for (x,y,w,h) in signsR:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        roi = img[y:y+h, x:x+w]
        roi = cv2.resize(roi, (200, 200))
    return img, roi


# Open Webcam
cap = cv2.VideoCapture(0)

while True:

    ret, frame = cap.read()
    
    image, signA = signA_detector(frame)
    image, signB = signB_detector(frame)
    image, signC = signC_detector(frame)
    image, signD = signD_detector(frame)
    image, signF = signF_detector(frame)
    image, signR = signR_detector(frame)
    
    try:
        signA = cv2.cvtColor(signA, cv2.COLOR_BGR2GRAY)
        signB = cv2.cvtColor(signB, cv2.COLOR_BGR2GRAY)
        signC = cv2.cvtColor(signC, cv2.COLOR_BGR2GRAY)
        signD = cv2.cvtColor(signD, cv2.COLOR_BGR2GRAY)
        signF = cv2.cvtColor(signF, cv2.COLOR_BGR2GRAY)
        signR = cv2.cvtColor(signR, cv2.COLOR_BGR2GRAY)

        # Pass face to prediction model
        # "results" comprises of a tuple containing the label and the confidence value
    
        cv2.putText(image, 'A', (100, 120), cv2.FONT_HERSHEY_COMPLEX, 1, (255,120,150), 2)
        
        cv2.putText(image, "Hey Akshat", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,255,0), 2)
        cv2.imshow('Face Recognition', image )
            
            #webbrowser.open('http://localhost:8888/notebooks/automatespeech.ipynb')
            #break
        
    except:
        cv2.putText(image, "No Face Found", (220, 120) , cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.putText(image, "Locked", (250, 450), cv2.FONT_HERSHEY_COMPLEX, 1, (0,0,255), 2)
        cv2.imshow('Face Recognition', image )
        pass
        
    if cv2.waitKey(1) == 27: #27 is the Esc Key
        break
        
cap.release()
cv2.destroyAllWindows()
